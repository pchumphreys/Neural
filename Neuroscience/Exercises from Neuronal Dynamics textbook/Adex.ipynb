# %% [markdown]
# # AdEx Neuron - Adaptive Exponential

# %% [markdown]
# Equations for AdEx Neuron:
#
# $$
# \begin{split}\left[\begin{array}{ccll}
# {\displaystyle \tau_m \frac{du}{dt}} &=& -(u-u_{rest}) + \Delta_T exp(\frac{u-\vartheta_{rh}}{\Delta_T}) - R w + R I(t) \\[.2cm]
# {\displaystyle \tau_w \frac{dw}{dt}} &=& a (u-u_{rest}) -w  + b \tau_w \sum_{t^{(f)}} \delta (t - t^{(f)})
#  \\[.2cm]
# \end{array}\right.\end{split}
# $$

# %%
% matplotlib inline
import matplotlib.pyplot as plt
import brian2 as b2
from neurodynex.adex_model import AdEx
from neurodynex.tools import plot_tools, input_factory

# %%
a= 0.0 * b2.nsiemens
b= 0. * b2.pamp
tau_w = 30. * b2.ms
tau_m = 20. * b2.ms
v_reset= -55. * b2.mvolt

current = input_factory.get_step_current(10, 250, 1. * b2.ms, 65.0 * b2.pA)
state_monitor, spike_monitor = AdEx.simulate_AdEx_neuron(I_stim=current, simulation_time=400 * b2.ms,
                                                         a = a, b= b,tau_w = tau_w,tau_m = tau_m,v_reset = v_reset)
plot_tools.plot_voltage_and_current_traces(state_monitor, current)
print("nr of spikes: {}".format(spike_monitor.count[0]))
plt.show()
plt.close()
AdEx.plot_adex_state(state_monitor)
# Out:
# nr of spikes: 17

# %%
a= 0.0 * b2.nsiemens
b= 60. * b2.pamp
tau_w = 30. * b2.ms
tau_m = 20. * b2.ms
v_reset= -55. * b2.mvolt

current = input_factory.get_step_current(10, 250, 1. * b2.ms, 65.0 * b2.pA)
state_monitor, spike_monitor = AdEx.simulate_AdEx_neuron(I_stim=current, simulation_time=400 * b2.ms,
                                                         a = a, b= b,tau_w = tau_w,tau_m = tau_m,v_reset = v_reset)
plot_tools.plot_voltage_and_current_traces(state_monitor, current)
print("nr of spikes: {}".format(spike_monitor.count[0]))
plt.show()
plt.close()
AdEx.plot_adex_state(state_monitor)
# Out:
# nr of spikes: 4

# %%
a= 0.0 * b2.nsiemens
b= 5. * b2.pamp
tau_w = 100. * b2.ms
tau_m = 20. * b2.ms
v_reset= -55. * b2.mvolt

current = input_factory.get_step_current(10, 250, 1. * b2.ms, 65.0 * b2.pA)
state_monitor, spike_monitor = AdEx.simulate_AdEx_neuron(I_stim=current, simulation_time=400 * b2.ms,
                                                         a = a, b= b,tau_w = tau_w,tau_m = tau_m,v_reset = v_reset)
plot_tools.plot_voltage_and_current_traces(state_monitor, current)
print("nr of spikes: {}".format(spike_monitor.count[0]))
plt.show()
plt.close()
AdEx.plot_adex_state(state_monitor)
# Out:
# nr of spikes: 10

# %%
a= 0.5 * b2.nsiemens
b= 7. * b2.pamp
tau_w = 100. * b2.ms
tau_m = 5. * b2.ms
v_reset= -55. * b2.mvolt

current = input_factory.get_step_current(10, 250, 1. * b2.ms, 65.0 * b2.pA)
state_monitor, spike_monitor = AdEx.simulate_AdEx_neuron(I_stim=current, simulation_time=400 * b2.ms,
                                                         a = a, b= b,tau_w = tau_w,tau_m = tau_m,v_reset = v_reset)
plot_tools.plot_voltage_and_current_traces(state_monitor, current)
print("nr of spikes: {}".format(spike_monitor.count[0]))
plt.show()
plt.close()
AdEx.plot_adex_state(state_monitor)
# Out:
# nr of spikes: 10
